# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
user_oldfile = pd.read_csv('data/datatest2.csv',index_col=0)
infomations = pd.read_csv('data/infomations_store.csv',index_col=0)
response = pd.read_csv('data/Form.csv',index_col=0)

# %%
user = user_oldfile.iloc[0:,[0,1,2]]

# %%
infomations.head(5)
# Out:
#                      store           type  \
# 0  NAP's Coffee & Roasters       speedbar
# 1                   sangob       speedbar
# 2                 SongSarn        slowbar
# 3            LIFE Roasters  hybrid,bakery
# 4              Nap x Warin       speedbar
#
#                                            address\t  \
# 0  49, 1 ถนน ศรีณรงค์ ตำบลในเมือง อำเภอเมืองอุบลร...
# 1    149 ถนน พรหมเทพ ในเมือง เมือง อุบลราชธานี 34000
# 2  ถ.พรหมเทพ ซอย.ข้างร้านรานี ที่มีStreet Art Mue...
# 3  202/3 ถนนสุริยาตร์ ตำบล ในเมือง อำเภอเมืองอุบล...
# 4  16 ถนนเทศบาล 9 ตำบล วารินชำราบ อำเภอวารินชำราบ...
#
#                                            plus_code   latitude   longitude  \
# 0  6VH8+F5 เทศบาลนครอุบลราชธานี อำเภอเมืองอุบลราช...  15.228920  104.865365
# 1  6VG5+3Q เทศบาลนครอุบลราชธานี อำเภอเมืองอุบลราช...  15.225389  104.859395
# 2  6VG5+4C เทศบาลนครอุบลราชธานี อำเภอเมืองอุบลราช...  15.225416  104.858555
# 3  6VQ6+3F เทศบาลนครอุบลราชธานี อำเภอเมืองอุบลราช...  15.237538  104.861231
# 4  5VR6+8Q ตำบล วารินชำราบ อำเภอวารินชำราบ อุบลรา...  15.190857  104.861934
#
#                                       amenities  \
# 0                                       Toilets
# 1                            Free Wi-Fi,Toilets
# 2                                       Toilets
# 3                                       Toilets
# 4  Free Wi-Fi,Good for kids,Toilets,Bar on site
#
#                                          menu coffee  \
# 0  hazelnut latte,vanilla latte,caramel latte,esp...
# 1  espresso,americano,cappuccino,mocha,latte,cold...
# 2  espresso,americano,cappuccino,mocha,latte,cold...
# 3  sparkling americano,tonic americano,caramel ma...
# 4  Espresso Sparkling Yuzu,Lychee Espresso Tonic,...
#
#                                      menu non coffee  rating  count_rating
# 0  Red Plum Sparking,Honey Lemon Sparking,Lychee ...     4.6           178
# 1  milk caremel,matcha milk,apple tea,peach tea,c...     4.7            57
# 2  cocoa,matcha,peach tea,vanilla ginger,thai tea...     4.6            52
# 3  Iced cocoa,Iced cocoa mint,Iced matcha latte,I...     4.6           255
# 4  Matcha Sparkling Yuzu,Yuzu Black Lemon Tea,Cho...     4.5            87

# %%
response.head(5)
# Out:
#                    Age  Gender  \
# Timestamp
# 1/3/2023 16:52:51   20    male
# 1/3/2023 16:59:44   16  female
# 1/3/2023 17:00:34   22    male
# 1/3/2023 17:00:50   21  female
# 1/3/2023 17:01:45   19    male
#
#                                                                Store  \
# Timestamp
# 1/3/2023 16:52:51  NAP's Coffee & Roasters, sangob, Nap x Warin, ...
# 1/3/2023 16:59:44  BalconyKiss Coffee, ROOF COFFEE, LAVA  JAVA Co...
# 1/3/2023 17:00:34    NAP's Coffee & Roasters, SongSarn, Yuanjai Cafe
# 1/3/2023 17:00:50  NAP's Coffee & Roasters, Nap x Warin, Snoopcat...
# 1/3/2023 17:01:45  NAP's Coffee & Roasters, sangob, Nap x Warin, ...
#
#                          menu  Rating                              amenities
# Timestamp
# 1/3/2023 16:52:51    espresso       4                Free Wi-Fi, Bar on site
# 1/3/2023 16:59:44       latte       4      Toilets, Free Wi-Fi, Good for kid
# 1/3/2023 17:00:34   americano       5   Free Wi-Fi, High chairs, Bar on site
# 1/3/2023 17:00:50       latte       5                    Toilets, Free Wi-Fi
# 1/3/2023 17:01:45  cappuccino       4  Free Wi-Fi, Good for kid, Bar on site

# %%
user.head(10)
# Out:
#                      Store                        User  Rating
# 0  NAP's Coffee & Roasters                   Nuunet D.     5.0
# 1  NAP's Coffee & Roasters                   vanai sun     3.0
# 2  NAP's Coffee & Roasters              Phonanan Seeon     5.0
# 3  NAP's Coffee & Roasters  Chavakorn Laophetsakunchai     5.0
# 4  NAP's Coffee & Roasters               community man     5.0
# 5  NAP's Coffee & Roasters                Oaddybeing B     5.0
# 6  NAP's Coffee & Roasters           Jarunya Buntherng     5.0
# 7  NAP's Coffee & Roasters                    fifi joo     4.0
# 8  NAP's Coffee & Roasters        YUWADEE WANGSANKLANG     4.0
# 9  NAP's Coffee & Roasters                 FatAmmy' DN     5.0

# %% [markdown]
# # visualization
#
# `find different data to learn recommendations with more method`

# %%
fig, axes = plt.subplots(1, 3,figsize=(12,5))
sns.histplot(data=response, x="Rating",bins=15,ax=axes[1])
sns.countplot(data=user, y="Store",ax=axes[0])
sns.boxplot(y=user['Rating'])
# Out:
# <AxesSubplot: ylabel='Rating'>

# %% [markdown]
# `find outlier`

# %%
user[user['Rating'] <= 2].groupby(['Store']).agg(['mean', 'count'])
# Out:
# C:\Users\Note\AppData\Local\Temp\ipykernel_24028\2482397105.py:1: FutureWarning: ['User'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   user[user['Rating'] <= 2].groupby(['Store']).agg(['mean', 'count'])
#                                Rating
#                                  mean count
# Store
# Anna Roasters                1.400000     5
# BaanHuakham Cafe & Farmstay  1.000000     1
# BalconyKiss Coffee           2.000000     2
# Blues Coffee                 1.333333     9
# Bossa cafe                   1.500000     6
# Commune Drink/Talk/Share     1.000000     1
# GODFATHER COFFEE             1.000000     2
# Impression Sunrise           1.666667     3
# LIFE Roasters                1.750000     4
# My Papilio                   1.500000     4
# NAP's Coffee & Roasters      1.500000     2
# Nap x Warin                  1.000000     2
# PENSER CAFE                  2.000000     1
# Phantae Coffee               1.500000     8
# ROOF COFFEE                  1.000000     1
# Saereesook                   1.333333     3
# Snoopcat Cafe                2.000000     1
# Stufe coffee                 2.000000     1
# Tree Cafe Rim Moon           1.357143    14

# %% [markdown]
# `find dupicate review`

# %%
check = user.groupby(user.User.tolist(),as_index=False).size()
check
# Out:
#                       index  size
# 0        01 มติมนต์ จํานงค์     1
# 1         113_kammika raksa     1
# 2                     1904x     1
# 3           1984whatthehell     2
# 4        212ปาณิตตา ศิริชัย     1
# ...                     ...   ...
# 2259  ไชยพนิตนันท์ ไกรวิเศษ     2
# 2260             ไชโย กินรี     1
# 2261             ไทยม๊อตโตะ     1
# 2262        ไพจิต ศิลารักษ์     1
# 2263              ไวไว อิอิ     2
#
# [2264 rows x 2 columns]

# %%
check
# Out:
#                       index  size
# 0        01 มติมนต์ จํานงค์     1
# 1         113_kammika raksa     1
# 2                     1904x     1
# 3           1984whatthehell     2
# 4        212ปาณิตตา ศิริชัย     1
# ...                     ...   ...
# 2259  ไชยพนิตนันท์ ไกรวิเศษ     2
# 2260             ไชโย กินรี     1
# 2261             ไทยม๊อตโตะ     1
# 2262        ไพจิต ศิลารักษ์     1
# 2263              ไวไว อิอิ     2
#
# [2264 rows x 2 columns]

# %% [markdown]
# # try recommendations with matrix svds
#
#
# ref
# `https://medium.com/@aliozan_memetoglu/5-dealing-with-sparsity-and-matrix-factorization-2df425bc2fae`

# %%
from scipy.sparse.linalg import svds
from scipy.sparse import csr_matrix

# %%
csr_matrix(df.values)
# Out:
# <4x3 sparse matrix of type '<class 'numpy.int64'>'
# 	with 12 stored elements in Compressed Sparse Row format>

# %%
user_item = user.pivot_table(values='Rating', index='User', columns='Store')

# %%
user_item = user_item.astype(float)

# %%
# Get the average rating for each user 
avg_ratings = user_item.mean(axis=1)
# Center each users ratings around 0
user_ratings_table_centered = user_item.sub(avg_ratings, axis=0)
# Fill in the missing data with 0s
user_ratings_table_normed = user_ratings_table_centered.fillna(0)

# %%
user_ratings_table_normed
# Out:
# Store                  11.11 Gallery and Coffee  Abe Specialty Coffee  Amarna  \
# User
# 01 มติมนต์ จํานงค์                          0.0                   0.0     0.0
# 113_kammika raksa                           0.0                   0.0     0.0
# 1904x                                       0.0                   0.0     0.0
# 1984whatthehell                             0.0                   0.0     0.0
# 212ปาณิตตา ศิริชัย                          0.0                   0.0     0.0
# ...                                         ...                   ...     ...
# ไชยพนิตนันท์ ไกรวิเศษ                       0.0                   0.0     0.0
# ไชโย กินรี                                  0.0                   0.0     0.0
# ไทยม๊อตโตะ                                  0.0                   0.0     0.0
# ไพจิต ศิลารักษ์                             0.0                   0.0     0.0
# ไวไว อิอิ                                   0.0                   0.0     0.0
#
# Store                  Anna Roasters  Attaroast  BaanHuakham Cafe & Farmstay  \
# User
# 01 มติมนต์ จํานงค์               0.0        0.0                          0.0
# 113_kammika raksa                0.0        0.0                          0.0
# 1904x                            0.0        0.0                          0.0
# 1984whatthehell                  0.0        0.0                          0.0
# 212ปาณิตตา ศิริชัย               0.0        0.0                          0.0
# ...                              ...        ...                          ...
# ไวไว อิอิ                       0.0                 0.0           0.0
#
# Store                  r o u n d  sangob
# User
# 01 มติมนต์ จํานงค์           0.0     0.0
# 113_kammika raksa            0.0     0.0
# 1904x                        0.0     0.0
# 1984whatthehell              0.0     0.0
# 212ปาณิตตา ศิริชัย           0.0     0.0
# ...                          ...     ...
# ไชยพนิตนันท์ ไกรวิเศษ        0.0     0.0
# ไชโย กินรี                   0.0     0.0
# ไทยม๊อตโตะ                   0.0     0.0
# ไพจิต ศิลารักษ์              0.0     0.0
# ไวไว อิอิ                    0.0     0.0
#
# [2264 rows x 34 columns]

# %%
csr_matrix(user_ratings_table_normed)
# Out:
# <2264x34 sparse matrix of type '<class 'numpy.float64'>'
# 	with 709 stored elements in Compressed Sparse Row format>

# %%
from scipy.sparse.linalg import svds

U, sigma, Vt = svds(matrix)

# %%
U
# Out:
# array([[-0.00860284,  0.00441207,  0.00505884,  0.00441946, -0.04225076,
#         -0.03797155],
#        [ 0.02232164,  0.00473377, -0.00255608,  0.00253539,  0.00324572,
#         -0.00750331],
#        [ 0.00364845,  0.00029775,  0.00031302,  0.00078556,  0.00213027,
#         -0.0018995 ],
#        ...,
#        [-0.03311494,  0.00253073, -0.04796849,  0.02709676,  0.02383223,
#         -0.01648567],
#        [-0.00972259,  0.01208166, -0.01522148, -0.06366378,  0.01251212,
#         -0.01325906],
#        [ 0.00725797,  0.0009051 , -0.00145721,  0.00134099,  0.00531021,
#         -0.00813872]])

# %%
# Convert sigma into a diagonal matrix
sigma = np.diag(sigma)
print(sigma)
# Out:
# [[60.90863996  0.          0.          0.          0.          0.        ]
#  [ 0.         61.77898698  0.          0.          0.          0.        ]
#  [ 0.          0.         66.4517305   0.          0.          0.        ]
#  [ 0.          0.          0.         70.74657236  0.          0.        ]
#  [ 0.          0.          0.          0.         79.98701331  0.        ]
#  [ 0.          0.          0.          0.          0.         93.93942365]]

# %%
# Dot product of U and sigma
U_sigma = np.dot(U, sigma)
# Dot product of result and Vt
U_sigma_Vt = np.dot(U_sigma, Vt)
# Add back on the row means contained in avg_ratings
uncentered_ratings = U_sigma_Vt + avg_ratings.values.reshape(-1, 1)
# Create DataFrame of the results
calc_pred_ratings_df = pd.DataFrame(uncentered_ratings, 
                                    index=user_item.index,
                                    columns=user_item.columns
                                   )
# Print both the recalculated matrix and the original 
print(calc_pred_ratings_df)
# Out:
# Store                  11.11 Gallery and Coffee  Abe Specialty Coffee  \
# User
# 01 มติมนต์ จํานงค์                     4.994718              4.978859
# 113_kammika raksa                      5.096791              5.059491
# 1904x                                  5.022823              5.013050
# 1984whatthehell                        5.159643              5.043252
# 212ปาณิตตา ศิริชัย                     5.026594              5.014942
# ...                                         ...                   ...
# ไชยพนิตนันท์ ไกรวิเศษ                  5.113120              5.035564
# ไชโย กินรี                             5.028355              5.016769
# ไทยม๊อตโตะ                             5.039210              4.994560
# 1904x                            4.994718      5.019103   5.004615  5.041790
# 1984whatthehell                  4.892267      5.207300   5.050509  5.097766
# 212ปาณิตตา ศิริชัย               5.035267      5.023235   5.005606  5.052649
# ...                                   ...           ...        ...       ...
# ไชยพนิตนันท์ ไกรวิเศษ            4.978300      5.138360   5.031294  5.209545
# ไชโย กินรี                       5.009044      5.024348   5.005911  5.053845
# ไทยม๊อตโตะ                       4.941826      5.075211   5.016316  5.061475
# ไพจิต ศิลารักษ์                  4.965230      4.977109   4.989971  5.007696
# ไวไว อิอิ                        5.214485      5.052191   5.012820  5.117107
#
# [2264 rows x 34 columns]

# %% [markdown]
# # try cosine with NerestNeighbors
# ref
# `https://www.kaggle.com/code/ecemboluk/recommendation-system-with-cf-using-knn`

# %%
from scipy.sparse.linalg import svds
import pandas as pd

# %%
test1 = user_item.fillna(0)

# %%
ma = csr_matrix(test1.values)

# %%
from sklearn.neighbors import NearestNeighbors

# %%
model = NearestNeighbors(metric= 'cosine',algorithm = 'brute',n_neighbors = 20)

# %%
model.fit(ma)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_neighbors=20)

# %%
aa = test1.T ## trans

# %%
query_index = np.random.choice(aa.shape[0])

# %%
print("Choosen Movie is: ",aa.index[query_index])
# Out:
# Choosen Movie is:  SongSarn

# %%
user_movie_table_matrix = csr_matrix(aa.values)
model_knn = NearestNeighbors(metric = 'cosine', algorithm = 'brute')
model_knn.fit(user_movie_table_matrix)
distances, indices = model_knn.kneighbors(aa.iloc[query_index,:].values.reshape(1,-1), n_neighbors = 7)

# %%
aa.iloc[query_index,:].values.reshape(1,-1)
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %%
movie = []
distance = []

for i in range(0, len(distances.flatten())):
    if i != 0:
        movie.append(aa.index[indices.flatten()[i]])
        distance.append(distances.flatten()[i])    

m=pd.Series(movie,name='movie')

d=pd.Series(distance,name='distance')
print(m,d)
recommend = pd.concat([m,d], axis=1)
recommend = recommend.sort_values('distance',ascending=False)

print('Recommendations for {0}:\n'.format(aa.index[query_index]))
for i in range(0,recommend.shape[0]):
    print('{0}: {1}, with distance of {2}'.format(i, recommend["movie"].iloc[i], recommend["distance"].iloc[i]))
# Out:
# 0                Amarna
# 1             REDCOFFEE
# 2      GODFATHER COFFEE
# 3             ROSIEHOLM
# 4    Impression Sunrise
# 5                sangob
# Name: movie, dtype: object 0    0.816450
# 1    0.854800
# 2    0.879078
# 3    0.883542
# 4    0.884893
# 5    0.893044
# Name: distance, dtype: float64
# Recommendations for SongSarn:
#
# 0: sangob, with distance of 0.8930444303499244
# 1: Impression Sunrise, with distance of 0.8848925167446028
# 2: ROSIEHOLM, with distance of 0.8835422429167391
# 3: GODFATHER COFFEE, with distance of 0.8790780720942752
# 4: REDCOFFEE, with distance of 0.8548002616506976
# 5: Amarna, with distance of 0.816450191350319
