# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # import data to pandas

# %%
df_form = pd.read_csv('../data/Form.csv')

# %%
df_form.head()
# Out:
#            Timestamp  Age  Gender  \
# 0  1/3/2023 16:52:51   20    male
# 1  1/3/2023 16:59:44   16  female
# 2  1/3/2023 17:00:34   22    male
# 3  1/3/2023 17:00:50   21  female
# 4  1/3/2023 17:01:45   19    male
#
#                                                Store        menu  Rating  \
# 0  NAP's Coffee & Roasters, sangob, Nap x Warin, ...    espresso       4
# 1  BalconyKiss Coffee, ROOF COFFEE, LAVA  JAVA Co...       latte       4
# 2    NAP's Coffee & Roasters, SongSarn, Yuanjai Cafe   americano       5
# 3  NAP's Coffee & Roasters, Nap x Warin, Snoopcat...       latte       5
# 4  NAP's Coffee & Roasters, sangob, Nap x Warin, ...  cappuccino       4
#
#                                amenities
# 0                Free Wi-Fi, Bar on site
# 1      Toilets, Free Wi-Fi, Good for kid
# 2   Free Wi-Fi, High chairs, Bar on site
# 3                    Toilets, Free Wi-Fi
# 4  Free Wi-Fi, Good for kid, Bar on site

# %%
df_real = pd.read_csv('./data/infomations_store.csv',index_col=0)

# %%
df_real.head()
# Out:
#                      store           type  \
# 0  NAP's Coffee & Roasters       speedbar
# 1                   sangob       speedbar
# 2                 SongSarn        slowbar
# 3            LIFE Roasters  hybrid,bakery
# 4              Nap x Warin       speedbar
#
#                                            address\t  \
# 0  49, 1 ถนน ศรีณรงค์ ตำบลในเมือง อำเภอเมืองอุบลร...
# 1    149 ถนน พรหมเทพ ในเมือง เมือง อุบลราชธานี 34000
# 2  ถ.พรหมเทพ ซอย.ข้างร้านรานี ที่มีStreet Art Mue...
# 3  202/3 ถนนสุริยาตร์ ตำบล ในเมือง อำเภอเมืองอุบล...
# 4  16 ถนนเทศบาล 9 ตำบล วารินชำราบ อำเภอวารินชำราบ...
#
#                                            plus_code   latitude   longitude  \
# 0  6VH8+F5 เทศบาลนครอุบลราชธานี อำเภอเมืองอุบลราช...  15.228920  104.865365
# 1  6VG5+3Q เทศบาลนครอุบลราชธานี อำเภอเมืองอุบลราช...  15.225389  104.859395
# 2  6VG5+4C เทศบาลนครอุบลราชธานี อำเภอเมืองอุบลราช...  15.225416  104.858555
# 3  6VQ6+3F เทศบาลนครอุบลราชธานี อำเภอเมืองอุบลราช...  15.237538  104.861231
# ...

# %%
df_user_review = pd.read_csv('./data/datatest2.csv ')
